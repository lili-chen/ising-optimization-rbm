# %%
from gibbs import *

# %%
file_name = "gs_maxcut.txt"
file1 = open(file_name,"r")
first_line = file1.readline()[:-1].split("\t") # first line

all_files = []
for line in file1:
    arr = line[:-1].split("\t")
    all_files += [[int(elem) for elem in arr]]

# %%
plot_max_cut_efficiency_continuous(0, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(1, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(2, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(3, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(4, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(5, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(6, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(7, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(8, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(9, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(10, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(11, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(12, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(13, 0, all_files, 50000)

# %%
plot_max_cut_efficiency_continuous(14, 0, all_files, 50000)
