# %%
from gibbs import *

# %%
plot_max_cut_efficiency_discrete("maxcut/N010-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N020-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N030-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N040-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N050-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N060-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N070-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N080-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N090-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N100-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N110-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N120-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N130-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N140-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N150-id00.txt", 10000, 5)
