# %%
from gibbs import *

# %%
plot_max_cut_efficiency_discrete("maxcut/N010-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N020-id00.txt", 10000, 5)

# %%
plot_max_cut_efficiency_discrete("maxcut/N030-id00.txt", 10000, 1)

# %%
plot_max_cut_efficiency("maxcut/N040-id00.txt", 100, 100)

# %%
plot_max_cut_efficiency("maxcut/N050-id00.txt", 100, 1)

# %%
plot_max_cut_efficiency("maxcut/N060-id00.txt", 100, 1)

# %%
plot_max_cut_efficiency("maxcut/N070-id00.txt", 1000, 1)

# %%
plot_max_cut_efficiency("maxcut/N080-id00.txt", 100, 1)

# %%
plot_max_cut_efficiency("maxcut/N090-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N100-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N110-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N120-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N130-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N140-id00.txt", 100000, 1000)

# %%
plot_max_cut_efficiency("maxcut/N150-id00.txt", 100000, 1000)
