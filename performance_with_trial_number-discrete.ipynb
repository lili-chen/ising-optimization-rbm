# %%
from gibbs import *

# %%
file_name = "gs_maxcut.txt"
file1 = open(file_name,"r")
first_line = file1.readline()[:-1].split("\t") # first line

all_files = []
for line in file1:
    arr = line[:-1].split("\t")
    all_files += [[int(elem) for elem in arr]]

# %%
plot_max_cut_efficiency_discrete(0, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(1, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(2, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(3, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(4, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(5, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(6, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(7, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(8, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(9, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(10, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(11, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(12, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(13, 0, all_files, 2000, 5)

# %%
plot_max_cut_efficiency_discrete(14, 0, all_files, 2000, 5)
