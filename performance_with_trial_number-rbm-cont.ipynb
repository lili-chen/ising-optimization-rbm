# %%
from gibbs import *

# %%
file_name = "gs_maxcut.txt"
file1 = open(file_name,"r")
first_line = file1.readline()[:-1].split("\t") # first line

all_files = []
for line in file1:
    arr = line[:-1].split("\t")
    all_files += [[int(elem) for elem in arr]]

# %%
plot_max_cut_efficiency_continuous_rbm(0, 0, all_files, 1000)

# %%
plot_max_cut_efficiency_continuous_rbm(1, 0, all_files, 200000)

# %%
plot_max_cut_efficiency_continuous_rbm(2, 0, all_files, 1000000)

# %%
plot_max_cut_efficiency_continuous_rbm(3, 0, all_files, 1000000)

# %%
plot_max_cut_efficiency_continuous_rbm(4, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(5, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(6, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(7, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(8, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(9, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(10, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(11, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(12, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(13, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm(14, 0, all_files, 1000000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:161: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]
