# %%
from gibbs import *

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N010-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N020-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N030-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N040-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N050-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N060-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N070-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N080-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N090-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N100-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N110-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N120-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N130-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N140-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]

# %%
plot_max_cut_efficiency_continuous_rbm("maxcut/N150-id00.txt", 10000)
# Out:
# /Users/lilichen/Desktop/mcmc/gibbs.py:115: RuntimeWarning: divide by zero encountered in double_scalars
#   times = [-np.log(1-np.random.uniform(0,1))/lambdas[i] for i in range(self.size)]
