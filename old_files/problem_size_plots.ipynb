# %%
import numpy as np
import random
import matplotlib.pyplot as plt

arr = [[10, 20, 30, 40, 50, 60, 70, 80, 90], 
       [0.977124183006536, 0.9692970571095572, 0.9590570737339975, 0.9451550889388296, 0.9475573002842822, 0.9342061143407705, 0.9335551153010538, 0.9450977035156123, 0.9398778676064357], 
       [1.0, 1.0, 0.9785714285714285, 0.9672131147540983, 0.9655172413793104, 0.9640151515151515, 0.972183588317107, 0.9643243243243244, 0.9647766323024055], 
       [0.8888888888888888, 0.9230769230769231, 0.9136690647482014, 0.9173553719008265, 0.9281914893617021, 0.897196261682243, 0.9015471167369902, 0.922497308934338, 0.9150943396226415]]
arr2 = np.array(arr)
plt.plot(arr2[0], arr2[2], label='max') # orange: max
plt.plot(arr2[0], arr2[1], label='mean') # blue: mean
plt.plot(arr2[0], arr2[3], label='min') # green: min
plt.legend()
plt.xlabel("MAX-CUT Problem Size (Number of Vertices)")
plt.ylabel("Accuracy (Output Cut Size / Correct Cut Size)")
plt.show()

# %%
data = np.array([[1.0, 1.0, 0.9411764705882353, 1.0, 1.0, 1.0, 0.8888888888888888, 1.0, 0.9411764705882353, 1.0],
        [1.0, 0.9393939393939394, 0.96875, 1.0, 1.0, 0.9696969696969697, 0.9692307692307692, 0.953125, 0.9696969696969697, 0.9230769230769231],
        [0.9642857142857143, 0.9708029197080292, 0.9642857142857143, 0.9568345323741008, 0.9785714285714285, 0.950354609929078, 0.9568345323741008, 0.9714285714285714, 0.9136690647482014, 0.9635036496350365],
        [0.959349593495935, 0.9173553719008265, 0.9672131147540983, 0.9338842975206612, 0.9416666666666667, 0.963265306122449, 0.946058091286307, 0.9469387755102041, 0.925, 0.9508196721311475],
        [0.9598930481283422, 0.938337801608579, 0.9365079365079365, 0.952, 0.9623655913978495, 0.9281914893617021, 0.9287598944591029, 0.9493333333333334, 0.9546666666666667, 0.9655172413793104],
        [0.9380863039399625, 0.897196261682243, 0.9305816135084428, 0.9456928838951311, 0.9640151515151515, 0.9109461966604824, 0.9489603024574669, 0.9584905660377359, 0.9199255121042831, 0.9281663516068053],
        [0.9583333333333334, 0.9130434782608695, 0.9329608938547486, 0.9015471167369902, 0.957004160887656, 0.972183588317107, 0.9207232267037552, 0.9399441340782123, 0.9276773296244785, 0.9121338912133892],
        [0.9513513513513514, 0.9469122426868906, 0.9438444924406048, 0.9320388349514563, 0.9643243243243244, 0.9557713052858684, 0.922497308934338, 0.9397849462365592, 0.9483315392895587, 0.9461206896551724],
        [0.948936170212766, 0.936480686695279, 0.9392123287671232, 0.9647766323024055, 0.9150943396226415, 0.9375, 0.9502145922746781, 0.9352088661551577, 0.9365351629502573, 0.934819897084048]])

stds = np.std(data, axis=1)

# %%
arr2 = np.array(arr)
plt.errorbar(arr2[0], arr2[1], stds, label='+/- 1 std')
plt.errorbar(arr2[0], arr2[1], label='mean')
plt.legend()
plt.xlabel("MAX-CUT Problem Size (Number of Vertices)")
plt.ylabel("Accuracy (Output Cut Size / Correct Cut Size)")
plt.show()
