# %%
from gibbs import *

# %%
plot_max_cut_efficiency_continuous("maxcut/N010-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N020-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N030-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N040-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N050-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N060-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N070-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N080-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N090-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N100-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N110-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N120-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N130-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N140-id00.txt", 10000)

# %%
plot_max_cut_efficiency_continuous("maxcut/N150-id00.txt", 10000)
